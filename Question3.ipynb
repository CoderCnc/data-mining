# %%
from coronavirus_tweets import *

# %%
df = read_csv_3('Corona_NLP_test.csv')
df
# Out:
#       UserName  ScreenName             Location     TweetAt  \
# 0            1       44953                  NYC  02-03-2020
# 1            2       44954          Seattle, WA  02-03-2020
# 2            3       44955                  NaN  02-03-2020
# 3            4       44956          Chicagoland  02-03-2020
# 4            5       44957  Melbourne, Victoria  03-03-2020
# ...        ...         ...                  ...         ...
# 3793      3794       48746            Israel ??  16-03-2020
# 3794      3795       48747       Farmington, NM  16-03-2020
# 3795      3796       48748        Haverford, PA  16-03-2020
# 3796      3797       48749                  NaN  16-03-2020
# 3797      3798       48750  Arlington, Virginia  16-03-2020
#
#                                           OriginalTweet           Sentiment
# 0     TRENDING: New Yorkers encounter empty supermar...  Extremely Negative
# 1     When I couldn't find hand sanitizer at Fred Me...            Positive
# ...

# %%
df.TweetAt.value_counts()
# This dataset is the train dataset.
# Out:
# TweetAt
# 13-03-2020    1233
# 12-03-2020     685
# 14-03-2020     614
# 15-03-2020     519
# 16-03-2020     472
# 11-03-2020     165
# 10-03-2020      54
# 09-03-2020      16
# 08-03-2020       9
# 04-03-2020       8
# 07-03-2020       7
# 05-03-2020       6
# 02-03-2020       4
# 03-03-2020       4
# 06-03-2020       2
# Name: count, dtype: int64

# %%
get_sentiments(df)
# Out:
# array(['Extremely Negative', 'Positive', 'Extremely Positive', 'Negative',
#        'Neutral'], dtype=object)

# %%
second_most_popular_sentiment(df)
# Out:
# 'Positive'

# %%
date_most_popular_tweets(df)
# Out:
# '13-03-2020'

# %%
df = lower_case(df)
df
# Out:
#       UserName  ScreenName             Location     TweetAt  \
# 0            1       44953                  NYC  02-03-2020
# 1            2       44954          Seattle, WA  02-03-2020
# 2            3       44955                  NaN  02-03-2020
# 3            4       44956          Chicagoland  02-03-2020
# 4            5       44957  Melbourne, Victoria  03-03-2020
# ...        ...         ...                  ...         ...
# 3793      3794       48746            Israel ??  16-03-2020
# 3794      3795       48747       Farmington, NM  16-03-2020
# 3795      3796       48748        Haverford, PA  16-03-2020
# 3796      3797       48749                  NaN  16-03-2020
# 3797      3798       48750  Arlington, Virginia  16-03-2020
#
#                                           OriginalTweet           Sentiment
# 0     trending: new yorkers encounter empty supermar...  Extremely Negative
# 1     when i couldn't find hand sanitizer at fred me...            Positive
# ...

# %%
df = remove_non_alphabetic_chars(df)
df
# Out:
#       UserName  ScreenName             Location     TweetAt  \
# 0            1       44953                  NYC  02-03-2020
# 1            2       44954          Seattle, WA  02-03-2020
# 2            3       44955                  NaN  02-03-2020
# 3            4       44956          Chicagoland  02-03-2020
# 4            5       44957  Melbourne, Victoria  03-03-2020
# ...        ...         ...                  ...         ...
# 3793      3794       48746            Israel ??  16-03-2020
# 3794      3795       48747       Farmington, NM  16-03-2020
# 3795      3796       48748        Haverford, PA  16-03-2020
# 3796      3797       48749                  NaN  16-03-2020
# 3797      3798       48750  Arlington, Virginia  16-03-2020
#
#                                           OriginalTweet           Sentiment
# 0     trending  new yorkers encounter empty supermar...  Extremely Negative
# 1     when i couldn t find hand sanitizer at fred me...            Positive
# ...

# %%
df = remove_multiple_consecutive_whitespaces(df)
df
# Out:
#       UserName  ScreenName             Location     TweetAt  \
# 0            1       44953                  NYC  02-03-2020
# 1            2       44954          Seattle, WA  02-03-2020
# 2            3       44955                  NaN  02-03-2020
# 3            4       44956          Chicagoland  02-03-2020
# 4            5       44957  Melbourne, Victoria  03-03-2020
# ...        ...         ...                  ...         ...
# 3793      3794       48746            Israel ??  16-03-2020
# 3794      3795       48747       Farmington, NM  16-03-2020
# 3795      3796       48748        Haverford, PA  16-03-2020
# 3796      3797       48749                  NaN  16-03-2020
# 3797      3798       48750  Arlington, Virginia  16-03-2020
#
#                                           OriginalTweet           Sentiment
# 0     trending  new yorkers encounter empty supermar...  Extremely Negative
# 1     when i couldn t find hand sanitizer at fred me...            Positive
# ...

# %%
tdf = tokenize(df)

# %%
tdf
# Out:
#       UserName  ScreenName             Location     TweetAt  \
# 0            1       44953                  NYC  02-03-2020
# 1            2       44954          Seattle, WA  02-03-2020
# 2            3       44955                  NaN  02-03-2020
# 3            4       44956          Chicagoland  02-03-2020
# 4            5       44957  Melbourne, Victoria  03-03-2020
# ...        ...         ...                  ...         ...
# 3793      3794       48746            Israel ??  16-03-2020
# 3794      3795       48747       Farmington, NM  16-03-2020
# 3795      3796       48748        Haverford, PA  16-03-2020
# 3796      3797       48749                  NaN  16-03-2020
# 3797      3798       48750  Arlington, Virginia  16-03-2020
#
#                                           OriginalTweet           Sentiment
# 0     [trending, new, yorkers, encounter, empty, sup...  Extremely Negative
# 1     [when, i, couldn, t, find, hand, sanitizer, at...            Positive
# ...

# %%
count_words_with_repetitions(tdf)
# Out:
# 133399

# %%
count_words_without_repetitions(tdf)
# Out:
# 13991

# %%
frequent_words(tdf,10)
# Out:
# ['the', 'to', 'covid', 't', 'and', 'of', 'a', 'in', 'co', 'https']

# %%
tdf = remove_stop_words(tdf)

# %%
tdf
# Out:
#       UserName  ScreenName             Location     TweetAt  \
# 0            1       44953                  NYC  02-03-2020
# 1            2       44954          Seattle, WA  02-03-2020
# 2            3       44955                  NaN  02-03-2020
# 3            4       44956          Chicagoland  02-03-2020
# 4            5       44957  Melbourne, Victoria  03-03-2020
# ...        ...         ...                  ...         ...
# 3793      3794       48746            Israel ??  16-03-2020
# 3794      3795       48747       Farmington, NM  16-03-2020
# 3795      3796       48748        Haverford, PA  16-03-2020
# 3796      3797       48749                  NaN  16-03-2020
# 3797      3798       48750  Arlington, Virginia  16-03-2020
#
#                                           OriginalTweet           Sentiment
# 0     [trending, yorkers, encounter, empty, supermar...  Extremely Negative
# 1     [couldn, find, hand, sanitizer, fred, meyer, t...            Positive
# ...

# %%
tdf = stemming(tdf)

# %%
tdf
# Out:
#       UserName  ScreenName             Location     TweetAt  \
# 0            1       44953                  NYC  02-03-2020
# 1            2       44954          Seattle, WA  02-03-2020
# 2            3       44955                  NaN  02-03-2020
# 3            4       44956          Chicagoland  02-03-2020
# 4            5       44957  Melbourne, Victoria  03-03-2020
# ...        ...         ...                  ...         ...
# 3793      3794       48746            Israel ??  16-03-2020
# 3794      3795       48747       Farmington, NM  16-03-2020
# 3795      3796       48748        Haverford, PA  16-03-2020
# 3796      3797       48749                  NaN  16-03-2020
# 3797      3798       48750  Arlington, Virginia  16-03-2020
#
#                                           OriginalTweet           Sentiment
# 0     [trend, yorker, encount, empti, supermarket, s...  Extremely Negative
# 1     [couldn, find, hand, sanit, fred, meyer, turn,...            Positive
# ...

# %%
frequent_words(tdf,10)

# Observation: Only the 'Coronavirus' word appeared in both analyses. The other words are different.
# Out:
# ['covid',
#  'http',
#  'coronaviru',
#  'food',
#  'store',
#  'stock',
#  'groceri',
#  'peopl',
#  'shop',
#  'amp']

# %%
df = read_csv_3('Corona_NLP_test.csv')

# %%
y_train, y_pred = mnb_predict(df)
y_train, y_pred
# Out:
# (array(['Positive', 'Positive', 'Extremely Negative', ...,
#         'Extremely Negative', 'Negative', 'Extremely Negative'],
#        dtype=object),
#  array(['Positive', 'Positive', 'Extremely Negative', ...,
#         'Extremely Negative', 'Negative', 'Extremely Negative'],
#        dtype=object))

# %%
mnb_accuracy(y_pred, y_train)
# Out:
# 0.863
