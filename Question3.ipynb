# %% [markdown]
# ## Question #3

# %% [markdown]
# ## 1.

# %%
from coronavirus_tweets import *

# %%
df = read_csv_3('coronavirus_tweets.csv')
df
# Out:
#        UserName  ScreenName                      Location     TweetAt  \
# 0          3799       48751                        London  16-03-2020
# 1          3800       48752                            UK  16-03-2020
# 2          3801       48753                     Vagabonds  16-03-2020
# 3          3802       48754                           NaN  16-03-2020
# 4          3803       48755                           NaN  16-03-2020
# ...         ...         ...                           ...         ...
# 41152     44951       89903  Wellington City, New Zealand  14-04-2020
# 41153     44952       89904                           NaN  14-04-2020
# 41154     44953       89905                           NaN  14-04-2020
# 41155     44954       89906                           NaN  14-04-2020
# 41156     44955       89907  i love you so much || he/him  14-04-2020
#
#                                            OriginalTweet           Sentiment
# ...

# %%
df.TweetAt.value_counts()
# Out:
# TweetAt
# 20-03-2020    3448
# 19-03-2020    3215
# 25-03-2020    2979
# 18-03-2020    2742
# 21-03-2020    2653
# 22-03-2020    2114
# 23-03-2020    2062
# 17-03-2020    1977
# 08-04-2020    1881
# 07-04-2020    1843
# 06-04-2020    1742
# 24-03-2020    1480
# 09-04-2020    1471
# 13-04-2020    1428
# 26-03-2020    1277
# 05-04-2020    1131
# 10-04-2020    1005
# 02-04-2020     954
# 11-04-2020     909
# 03-04-2020     810
# 12-04-2020     803
# 04-04-2020     767
# 16-03-2020     656
# 01-04-2020     630
# 27-03-2020     345
# 31-03-2020     316
# 14-04-2020     284
# 29-03-2020     125
# 30-03-2020      87
# 28-03-2020      23
# Name: count, dtype: int64

# %%
get_sentiments(df)
# Out:
# array(['Neutral', 'Positive', 'Extremely Negative', 'Negative',
#        'Extremely Positive'], dtype=object)

# %%
second_most_popular_sentiment(df)
# Out:
# 'Negative'

# %%
date_most_popular_tweets(df)
# Out:
# '25-03-2020'

# %%
df = lower_case(df)
df
# Out:
#        UserName  ScreenName                      Location     TweetAt  \
# 0          3799       48751                        London  16-03-2020
# 1          3800       48752                            UK  16-03-2020
# 2          3801       48753                     Vagabonds  16-03-2020
# 3          3802       48754                           NaN  16-03-2020
# 4          3803       48755                           NaN  16-03-2020
# ...         ...         ...                           ...         ...
# 41152     44951       89903  Wellington City, New Zealand  14-04-2020
# 41153     44952       89904                           NaN  14-04-2020
# 41154     44953       89905                           NaN  14-04-2020
# 41155     44954       89906                           NaN  14-04-2020
# 41156     44955       89907  i love you so much || he/him  14-04-2020
#
#                                            OriginalTweet           Sentiment
# ...

# %%
df = remove_non_alphabetic_chars(df)
df
# Out:
#        UserName  ScreenName                      Location     TweetAt  \
# 0          3799       48751                        London  16-03-2020
# 1          3800       48752                            UK  16-03-2020
# 2          3801       48753                     Vagabonds  16-03-2020
# 3          3802       48754                           NaN  16-03-2020
# 4          3803       48755                           NaN  16-03-2020
# ...         ...         ...                           ...         ...
# 41152     44951       89903  Wellington City, New Zealand  14-04-2020
# 41153     44952       89904                           NaN  14-04-2020
# 41154     44953       89905                           NaN  14-04-2020
# 41155     44954       89906                           NaN  14-04-2020
# 41156     44955       89907  i love you so much || he/him  14-04-2020
#
#                                            OriginalTweet           Sentiment
# ...

# %%
df = remove_multiple_consecutive_whitespaces(df)
df
# Out:
#        UserName  ScreenName                      Location     TweetAt  \
# 0          3799       48751                        London  16-03-2020
# 1          3800       48752                            UK  16-03-2020
# 2          3801       48753                     Vagabonds  16-03-2020
# 3          3802       48754                           NaN  16-03-2020
# 4          3803       48755                           NaN  16-03-2020
# ...         ...         ...                           ...         ...
# 41152     44951       89903  Wellington City, New Zealand  14-04-2020
# 41153     44952       89904                           NaN  14-04-2020
# 41154     44953       89905                           NaN  14-04-2020
# 41155     44954       89906                           NaN  14-04-2020
# 41156     44955       89907  i love you so much || he/him  14-04-2020
#
#                                            OriginalTweet           Sentiment
# ...

# %%
tdf = tokenize(df)
tdf
# Out:
#        UserName  ScreenName                      Location     TweetAt  \
# 0          3799       48751                        London  16-03-2020
# 1          3800       48752                            UK  16-03-2020
# 2          3801       48753                     Vagabonds  16-03-2020
# 3          3802       48754                           NaN  16-03-2020
# 4          3803       48755                           NaN  16-03-2020
# ...         ...         ...                           ...         ...
# 41152     44951       89903  Wellington City, New Zealand  14-04-2020
# 41153     44952       89904                           NaN  14-04-2020
# 41154     44953       89905                           NaN  14-04-2020
# 41155     44954       89906                           NaN  14-04-2020
# 41156     44955       89907  i love you so much || he/him  14-04-2020
#
#                                            OriginalTweet           Sentiment
# ...

# %%
count_words_with_repetitions(tdf)
# Out:
# 1351476

# %%
count_words_without_repetitions(tdf) #check if this function returns the correct value
# Out:
# 80067

# %%
frequent_words(tdf,10)
# Out:
# ['the', 'to', 't', 'co', 'and', 'https', 'covid', 'of', 'a', 'in']

# %%
tdf = remove_stop_words(tdf)
tdf
# Out:
#        UserName  ScreenName                      Location     TweetAt  \
# 0          3799       48751                        London  16-03-2020
# 1          3800       48752                            UK  16-03-2020
# 2          3801       48753                     Vagabonds  16-03-2020
# 3          3802       48754                           NaN  16-03-2020
# 4          3803       48755                           NaN  16-03-2020
# ...         ...         ...                           ...         ...
# 41152     44951       89903  Wellington City, New Zealand  14-04-2020
# 41153     44952       89904                           NaN  14-04-2020
# 41154     44953       89905                           NaN  14-04-2020
# 41155     44954       89906                           NaN  14-04-2020
# 41156     44955       89907  i love you so much || he/him  14-04-2020
#
#                                            OriginalTweet           Sentiment
# ...

# %%
frequent_words(tdf,10)
# Out:
# ['https',
#  'covid',
#  'coronavirus',
#  'prices',
#  'food',
#  'supermarket',
#  'store',
#  'grocery',
#  'people',
#  'amp']

# %%
tdf = stemming(tdf)
tdf
# Out:
#        UserName  ScreenName                      Location     TweetAt  \
# 0          3799       48751                        London  16-03-2020
# 1          3800       48752                            UK  16-03-2020
# 2          3801       48753                     Vagabonds  16-03-2020
# 3          3802       48754                           NaN  16-03-2020
# 4          3803       48755                           NaN  16-03-2020
# ...         ...         ...                           ...         ...
# 41152     44951       89903  Wellington City, New Zealand  14-04-2020
# 41153     44952       89904                           NaN  14-04-2020
# 41154     44953       89905                           NaN  14-04-2020
# 41155     44954       89906                           NaN  14-04-2020
# 41156     44955       89907  i love you so much || he/him  14-04-2020
#
#                                            OriginalTweet           Sentiment
# ...

# %%
frequent_words(tdf,10)

# Observation: The words 'covid' and 'http' appeared in both analyses. The other words are different.
# Out:
# ['http',
#  'covid',
#  'coronaviru',
#  'price',
#  'store',
#  'supermarket',
#  'food',
#  'groceri',
#  'peopl',
#  'consum']

# %%
df = read_csv_3('coronavirus_tweets.csv')

# %%
y_pred = mnb_predict(df)
y_pred
# Out:
# array(['Neutral', 'Positive', 'Positive', ..., 'Positive', 'Positive',
#        'Negative'], dtype=object)

# %%
df['Sentiment']
# Out:
# 0                   Neutral
# 1                  Positive
# 2                  Positive
# 3                  Positive
# 4        Extremely Negative
#                 ...
# 41152               Neutral
# 41153    Extremely Negative
# 41154              Positive
# 41155               Neutral
# 41156              Negative
# Name: Sentiment, Length: 41157, dtype: object

# %%
y_true = df['Sentiment']
mnb_accuracy(y_pred, y_true)
# Out:
# 0.904
